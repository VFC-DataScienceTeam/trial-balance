# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
on this notebooks/script 

create a function that will laod all the files on the target folder 




consol all the target columsn and get the unique data

create A MONTHLY COL
